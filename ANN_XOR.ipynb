# %% [markdown]
# <a href="https://colab.research.google.com/github/Shriya661/NNDL_LAB/blob/main/ANN_XOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install keras==2.8
# Out:
# Requirement already satisfied: keras==2.8 in /usr/local/lib/python3.7/dist-packages (2.8.0)

# %%
pip install --upgrade tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (2.8.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.24.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.17.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow) (57.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.14.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (4.1.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.21.6)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.15.0)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 5.1 MB/s
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.44.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (13.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow) (1.5.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (3.3.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.35.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.23.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.6.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (3.2.0)
# Installing collected packages: tf-estimator-nightly
# Successfully installed tf-estimator-nightly-2.8.0.dev2021122109

# %%
pip install --upgrade tensorflow-gpu
# Out:
# Collecting tensorflow-gpu
#   Downloading tensorflow_gpu-2.8.0-cp37-cp37m-manylinux2010_x86_64.whl (497.5 MB)
#      |████████████████████████████████| 497.5 MB 25 kB/s
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.0.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (3.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (2.8.0.dev2021122109)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.44.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.14.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (2.8.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (4.1.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (0.24.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (13.0.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (3.17.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (57.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (2.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (2.8.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.21.6)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow-gpu) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow-gpu) (1.5.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (3.3.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (2.23.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (0.4.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (1.0.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow-gpu) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow-gpu) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow-gpu) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow-gpu) (3.2.0)
# Installing collected packages: tensorflow-gpu
# Successfully installed tensorflow-gpu-2.8.0

# %%
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense

# %%
training_data = np.array([[0,0],[0,1],[1,0],[1,1]])

# %%
target_data = np.array([[0],[1],[1],[0]])

# %%
model= Sequential()
model.add(Dense(16, input_dim=2, activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(loss='mean_squared_error',
              optimizer='adam',
              metrics=['binary_accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                48
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 65
# Trainable params: 65
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(training_data, target_data, epochs=250, verbose=2)
# Out:
# Epoch 1/250
# 1/1 - 0s - loss: 0.2731 - binary_accuracy: 0.5000 - 471ms/epoch - 471ms/step
# Epoch 2/250
# 1/1 - 0s - loss: 0.2723 - binary_accuracy: 0.2500 - 7ms/epoch - 7ms/step
# Epoch 3/250
# 1/1 - 0s - loss: 0.2716 - binary_accuracy: 0.2500 - 7ms/epoch - 7ms/step
# Epoch 4/250
# 1/1 - 0s - loss: 0.2708 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 5/250
# 1/1 - 0s - loss: 0.2700 - binary_accuracy: 0.2500 - 6ms/epoch - 6ms/step
# Epoch 6/250
# 1/1 - 0s - loss: 0.2693 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 7/250
# 1/1 - 0s - loss: 0.2686 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 8/250
# 1/1 - 0s - loss: 0.2679 - binary_accuracy: 0.2500 - 6ms/epoch - 6ms/step
# Epoch 9/250
# 1/1 - 0s - loss: 0.2671 - binary_accuracy: 0.2500 - 6ms/epoch - 6ms/step
# Epoch 10/250
# 1/1 - 0s - loss: 0.2664 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 11/250
# 1/1 - 0s - loss: 0.2657 - binary_accuracy: 0.2500 - 9ms/epoch - 9ms/step
# Epoch 12/250
# 1/1 - 0s - loss: 0.2650 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 13/250
# 1/1 - 0s - loss: 0.2644 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 14/250
# 1/1 - 0s - loss: 0.2637 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 15/250
# 1/1 - 0s - loss: 0.2630 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 16/250
# 1/1 - 0s - loss: 0.2623 - binary_accuracy: 0.2500 - 6ms/epoch - 6ms/step
# Epoch 17/250
# 1/1 - 0s - loss: 0.2617 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 18/250
# 1/1 - 0s - loss: 0.2611 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 19/250
# 1/1 - 0s - loss: 0.2604 - binary_accuracy: 0.2500 - 6ms/epoch - 6ms/step
# Epoch 20/250
# 1/1 - 0s - loss: 0.2598 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 21/250
# 1/1 - 0s - loss: 0.2592 - binary_accuracy: 0.2500 - 6ms/epoch - 6ms/step
# Epoch 22/250
# 1/1 - 0s - loss: 0.2586 - binary_accuracy: 0.2500 - 6ms/epoch - 6ms/step
# Epoch 23/250
# 1/1 - 0s - loss: 0.2580 - binary_accuracy: 0.2500 - 6ms/epoch - 6ms/step
# Epoch 24/250
# 1/1 - 0s - loss: 0.2575 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 25/250
# 1/1 - 0s - loss: 0.2569 - binary_accuracy: 0.2500 - 6ms/epoch - 6ms/step
# Epoch 26/250
# 1/1 - 0s - loss: 0.2564 - binary_accuracy: 0.2500 - 7ms/epoch - 7ms/step
# Epoch 27/250
# 1/1 - 0s - loss: 0.2559 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 28/250
# 1/1 - 0s - loss: 0.2553 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 29/250
# 1/1 - 0s - loss: 0.2548 - binary_accuracy: 0.2500 - 6ms/epoch - 6ms/step
# Epoch 30/250
# 1/1 - 0s - loss: 0.2543 - binary_accuracy: 0.2500 - 7ms/epoch - 7ms/step
# Epoch 31/250
# 1/1 - 0s - loss: 0.2538 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 32/250
# 1/1 - 0s - loss: 0.2533 - binary_accuracy: 0.2500 - 6ms/epoch - 6ms/step
# Epoch 33/250
# 1/1 - 0s - loss: 0.2528 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 34/250
# 1/1 - 0s - loss: 0.2523 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 35/250
# 1/1 - 0s - loss: 0.2518 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 36/250
# 1/1 - 0s - loss: 0.2513 - binary_accuracy: 0.2500 - 6ms/epoch - 6ms/step
# Epoch 37/250
# 1/1 - 0s - loss: 0.2509 - binary_accuracy: 0.2500 - 6ms/epoch - 6ms/step
# Epoch 38/250
# 1/1 - 0s - loss: 0.2504 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 39/250
# 1/1 - 0s - loss: 0.2499 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 40/250
# 1/1 - 0s - loss: 0.2495 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 41/250
# 1/1 - 0s - loss: 0.2490 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 42/250
# 1/1 - 0s - loss: 0.2486 - binary_accuracy: 0.2500 - 6ms/epoch - 6ms/step
# Epoch 43/250
# 1/1 - 0s - loss: 0.2481 - binary_accuracy: 0.2500 - 6ms/epoch - 6ms/step
# Epoch 44/250
# 1/1 - 0s - loss: 0.2477 - binary_accuracy: 0.2500 - 7ms/epoch - 7ms/step
# Epoch 45/250
# 1/1 - 0s - loss: 0.2473 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 46/250
# 1/1 - 0s - loss: 0.2468 - binary_accuracy: 0.2500 - 6ms/epoch - 6ms/step
# Epoch 47/250
# 1/1 - 0s - loss: 0.2464 - binary_accuracy: 0.2500 - 6ms/epoch - 6ms/step
# Epoch 48/250
# 1/1 - 0s - loss: 0.2460 - binary_accuracy: 0.2500 - 8ms/epoch - 8ms/step
# Epoch 49/250
# 1/1 - 0s - loss: 0.2456 - binary_accuracy: 0.2500 - 8ms/epoch - 8ms/step
# Epoch 50/250
# 1/1 - 0s - loss: 0.2452 - binary_accuracy: 0.2500 - 7ms/epoch - 7ms/step
# Epoch 51/250
# 1/1 - 0s - loss: 0.2448 - binary_accuracy: 0.2500 - 7ms/epoch - 7ms/step
# Epoch 52/250
# 1/1 - 0s - loss: 0.2444 - binary_accuracy: 0.2500 - 6ms/epoch - 6ms/step
# Epoch 53/250
# 1/1 - 0s - loss: 0.2440 - binary_accuracy: 0.2500 - 6ms/epoch - 6ms/step
# Epoch 54/250
# 1/1 - 0s - loss: 0.2436 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 55/250
# 1/1 - 0s - loss: 0.2432 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 56/250
# 1/1 - 0s - loss: 0.2427 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 57/250
# 1/1 - 0s - loss: 0.2423 - binary_accuracy: 0.2500 - 6ms/epoch - 6ms/step
# Epoch 58/250
# 1/1 - 0s - loss: 0.2419 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 59/250
# 1/1 - 0s - loss: 0.2415 - binary_accuracy: 0.2500 - 6ms/epoch - 6ms/step
# Epoch 60/250
# 1/1 - 0s - loss: 0.2411 - binary_accuracy: 0.2500 - 6ms/epoch - 6ms/step
# Epoch 61/250
# 1/1 - 0s - loss: 0.2407 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 62/250
# 1/1 - 0s - loss: 0.2403 - binary_accuracy: 0.5000 - 5ms/epoch - 5ms/step
# Epoch 63/250
# 1/1 - 0s - loss: 0.2399 - binary_accuracy: 0.5000 - 4ms/epoch - 4ms/step
# Epoch 64/250
# 1/1 - 0s - loss: 0.2395 - binary_accuracy: 0.5000 - 5ms/epoch - 5ms/step
# Epoch 65/250
# 1/1 - 0s - loss: 0.2391 - binary_accuracy: 0.5000 - 5ms/epoch - 5ms/step
# Epoch 66/250
# 1/1 - 0s - loss: 0.2386 - binary_accuracy: 0.5000 - 5ms/epoch - 5ms/step
# Epoch 67/250
# 1/1 - 0s - loss: 0.2382 - binary_accuracy: 0.5000 - 5ms/epoch - 5ms/step
# Epoch 68/250
# 1/1 - 0s - loss: 0.2378 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 69/250
# 1/1 - 0s - loss: 0.2374 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 70/250
# 1/1 - 0s - loss: 0.2370 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 71/250
# 1/1 - 0s - loss: 0.2366 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 72/250
# 1/1 - 0s - loss: 0.2362 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 73/250
# 1/1 - 0s - loss: 0.2358 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 74/250
# 1/1 - 0s - loss: 0.2355 - binary_accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 75/250
# 1/1 - 0s - loss: 0.2351 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 76/250
# 1/1 - 0s - loss: 0.2347 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 77/250
# 1/1 - 0s - loss: 0.2343 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 78/250
# 1/1 - 0s - loss: 0.2339 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 79/250
# 1/1 - 0s - loss: 0.2335 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 80/250
# 1/1 - 0s - loss: 0.2331 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 81/250
# 1/1 - 0s - loss: 0.2327 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 82/250
# 1/1 - 0s - loss: 0.2324 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 83/250
# 1/1 - 0s - loss: 0.2320 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 84/250
# 1/1 - 0s - loss: 0.2316 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 85/250
# 1/1 - 0s - loss: 0.2312 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 86/250
# 1/1 - 0s - loss: 0.2308 - binary_accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 87/250
# 1/1 - 0s - loss: 0.2305 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 88/250
# 1/1 - 0s - loss: 0.2301 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 89/250
# 1/1 - 0s - loss: 0.2297 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 90/250
# 1/1 - 0s - loss: 0.2293 - binary_accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 91/250
# 1/1 - 0s - loss: 0.2289 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 92/250
# 1/1 - 0s - loss: 0.2286 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 93/250
# 1/1 - 0s - loss: 0.2282 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 94/250
# 1/1 - 0s - loss: 0.2278 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 95/250
# 1/1 - 0s - loss: 0.2274 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 96/250
# 1/1 - 0s - loss: 0.2271 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 97/250
# 1/1 - 0s - loss: 0.2267 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 98/250
# 1/1 - 0s - loss: 0.2263 - binary_accuracy: 0.7500 - 10ms/epoch - 10ms/step
# Epoch 99/250
# 1/1 - 0s - loss: 0.2259 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 100/250
# 1/1 - 0s - loss: 0.2256 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 101/250
# 1/1 - 0s - loss: 0.2252 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 102/250
# 1/1 - 0s - loss: 0.2248 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 103/250
# 1/1 - 0s - loss: 0.2245 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 104/250
# 1/1 - 0s - loss: 0.2241 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 105/250
# 1/1 - 0s - loss: 0.2238 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 106/250
# 1/1 - 0s - loss: 0.2234 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 107/250
# 1/1 - 0s - loss: 0.2230 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 108/250
# 1/1 - 0s - loss: 0.2227 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 109/250
# 1/1 - 0s - loss: 0.2223 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 110/250
# 1/1 - 0s - loss: 0.2220 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 111/250
# 1/1 - 0s - loss: 0.2216 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 112/250
# 1/1 - 0s - loss: 0.2212 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 113/250
# 1/1 - 0s - loss: 0.2209 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 114/250
# 1/1 - 0s - loss: 0.2205 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 115/250
# 1/1 - 0s - loss: 0.2202 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 116/250
# 1/1 - 0s - loss: 0.2198 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 117/250
# 1/1 - 0s - loss: 0.2194 - binary_accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 118/250
# 1/1 - 0s - loss: 0.2191 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 119/250
# 1/1 - 0s - loss: 0.2187 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 120/250
# 1/1 - 0s - loss: 0.2183 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 121/250
# 1/1 - 0s - loss: 0.2180 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 122/250
# 1/1 - 0s - loss: 0.2176 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 123/250
# 1/1 - 0s - loss: 0.2172 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 124/250
# 1/1 - 0s - loss: 0.2169 - binary_accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 125/250
# 1/1 - 0s - loss: 0.2165 - binary_accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 126/250
# 1/1 - 0s - loss: 0.2161 - binary_accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 127/250
# 1/1 - 0s - loss: 0.2158 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 128/250
# 1/1 - 0s - loss: 0.2154 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 129/250
# 1/1 - 0s - loss: 0.2150 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 130/250
# 1/1 - 0s - loss: 0.2147 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 131/250
# 1/1 - 0s - loss: 0.2143 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 132/250
# 1/1 - 0s - loss: 0.2139 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 133/250
# 1/1 - 0s - loss: 0.2135 - binary_accuracy: 0.7500 - 10ms/epoch - 10ms/step
# Epoch 134/250
# 1/1 - 0s - loss: 0.2132 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 135/250
# 1/1 - 0s - loss: 0.2128 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 136/250
# 1/1 - 0s - loss: 0.2124 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 137/250
# 1/1 - 0s - loss: 0.2120 - binary_accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 138/250
# 1/1 - 0s - loss: 0.2117 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 139/250
# 1/1 - 0s - loss: 0.2113 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 140/250
# 1/1 - 0s - loss: 0.2109 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 141/250
# 1/1 - 0s - loss: 0.2105 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 142/250
# 1/1 - 0s - loss: 0.2101 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 143/250
# 1/1 - 0s - loss: 0.2098 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 144/250
# 1/1 - 0s - loss: 0.2094 - binary_accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 145/250
# 1/1 - 0s - loss: 0.2090 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 146/250
# 1/1 - 0s - loss: 0.2086 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 147/250
# 1/1 - 0s - loss: 0.2082 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 148/250
# 1/1 - 0s - loss: 0.2078 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 149/250
# 1/1 - 0s - loss: 0.2075 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 150/250
# 1/1 - 0s - loss: 0.2071 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 151/250
# 1/1 - 0s - loss: 0.2067 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 152/250
# 1/1 - 0s - loss: 0.2063 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 153/250
# 1/1 - 0s - loss: 0.2059 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 154/250
# 1/1 - 0s - loss: 0.2055 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 155/250
# 1/1 - 0s - loss: 0.2051 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 156/250
# 1/1 - 0s - loss: 0.2047 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 157/250
# 1/1 - 0s - loss: 0.2043 - binary_accuracy: 0.7500 - 11ms/epoch - 11ms/step
# Epoch 158/250
# 1/1 - 0s - loss: 0.2039 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 159/250
# 1/1 - 0s - loss: 0.2036 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 160/250
# 1/1 - 0s - loss: 0.2032 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 161/250
# 1/1 - 0s - loss: 0.2028 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 162/250
# 1/1 - 0s - loss: 0.2024 - binary_accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 163/250
# 1/1 - 0s - loss: 0.2020 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 164/250
# 1/1 - 0s - loss: 0.2016 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 165/250
# 1/1 - 0s - loss: 0.2012 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 166/250
# 1/1 - 0s - loss: 0.2008 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 167/250
# 1/1 - 0s - loss: 0.2004 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 168/250
# 1/1 - 0s - loss: 0.2000 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 169/250
# 1/1 - 0s - loss: 0.1996 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 170/250
# 1/1 - 0s - loss: 0.1992 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 171/250
# 1/1 - 0s - loss: 0.1988 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 172/250
# 1/1 - 0s - loss: 0.1984 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 173/250
# 1/1 - 0s - loss: 0.1980 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 174/250
# 1/1 - 0s - loss: 0.1976 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 175/250
# 1/1 - 0s - loss: 0.1972 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 176/250
# 1/1 - 0s - loss: 0.1968 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 177/250
# 1/1 - 0s - loss: 0.1964 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 178/250
# 1/1 - 0s - loss: 0.1960 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 179/250
# 1/1 - 0s - loss: 0.1956 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 180/250
# 1/1 - 0s - loss: 0.1952 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 181/250
# 1/1 - 0s - loss: 0.1948 - binary_accuracy: 0.7500 - 12ms/epoch - 12ms/step
# Epoch 182/250
# 1/1 - 0s - loss: 0.1944 - binary_accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 183/250
# 1/1 - 0s - loss: 0.1940 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 184/250
# 1/1 - 0s - loss: 0.1936 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 185/250
# 1/1 - 0s - loss: 0.1932 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 186/250
# 1/1 - 0s - loss: 0.1928 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 187/250
# 1/1 - 0s - loss: 0.1924 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 188/250
# 1/1 - 0s - loss: 0.1919 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 189/250
# 1/1 - 0s - loss: 0.1915 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 190/250
# 1/1 - 0s - loss: 0.1911 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 191/250
# 1/1 - 0s - loss: 0.1907 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 192/250
# 1/1 - 0s - loss: 0.1903 - binary_accuracy: 0.7500 - 10ms/epoch - 10ms/step
# Epoch 193/250
# 1/1 - 0s - loss: 0.1899 - binary_accuracy: 0.7500 - 11ms/epoch - 11ms/step
# Epoch 194/250
# 1/1 - 0s - loss: 0.1895 - binary_accuracy: 0.7500 - 14ms/epoch - 14ms/step
# Epoch 195/250
# 1/1 - 0s - loss: 0.1891 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 196/250
# 1/1 - 0s - loss: 0.1887 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 197/250
# 1/1 - 0s - loss: 0.1882 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 198/250
# 1/1 - 0s - loss: 0.1878 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 199/250
# 1/1 - 0s - loss: 0.1874 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 200/250
# 1/1 - 0s - loss: 0.1870 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 201/250
# 1/1 - 0s - loss: 0.1866 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 202/250
# 1/1 - 0s - loss: 0.1862 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 203/250
# 1/1 - 0s - loss: 0.1858 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 204/250
# 1/1 - 0s - loss: 0.1853 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 205/250
# 1/1 - 0s - loss: 0.1849 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 206/250
# 1/1 - 0s - loss: 0.1845 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 207/250
# 1/1 - 0s - loss: 0.1841 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 208/250
# 1/1 - 0s - loss: 0.1837 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 209/250
# 1/1 - 0s - loss: 0.1833 - binary_accuracy: 0.7500 - 10ms/epoch - 10ms/step
# Epoch 210/250
# 1/1 - 0s - loss: 0.1828 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 211/250
# 1/1 - 0s - loss: 0.1824 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 212/250
# 1/1 - 0s - loss: 0.1820 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 213/250
# 1/1 - 0s - loss: 0.1816 - binary_accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 214/250
# 1/1 - 0s - loss: 0.1812 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 215/250
# 1/1 - 0s - loss: 0.1807 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 216/250
# 1/1 - 0s - loss: 0.1803 - binary_accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 217/250
# 1/1 - 0s - loss: 0.1799 - binary_accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 218/250
# 1/1 - 0s - loss: 0.1795 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 219/250
# 1/1 - 0s - loss: 0.1790 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 220/250
# 1/1 - 0s - loss: 0.1786 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 221/250
# 1/1 - 0s - loss: 0.1782 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 222/250
# 1/1 - 0s - loss: 0.1778 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 223/250
# 1/1 - 0s - loss: 0.1773 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 224/250
# 1/1 - 0s - loss: 0.1769 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 225/250
# 1/1 - 0s - loss: 0.1765 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 226/250
# 1/1 - 0s - loss: 0.1761 - binary_accuracy: 1.0000 - 9ms/epoch - 9ms/step
# Epoch 227/250
# 1/1 - 0s - loss: 0.1757 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 228/250
# 1/1 - 0s - loss: 0.1752 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 229/250
# 1/1 - 0s - loss: 0.1748 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 230/250
# 1/1 - 0s - loss: 0.1744 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 231/250
# 1/1 - 0s - loss: 0.1740 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 232/250
# 1/1 - 0s - loss: 0.1735 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 233/250
# 1/1 - 0s - loss: 0.1731 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 234/250
# 1/1 - 0s - loss: 0.1727 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 235/250
# 1/1 - 0s - loss: 0.1722 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 236/250
# 1/1 - 0s - loss: 0.1718 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 237/250
# 1/1 - 0s - loss: 0.1714 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 238/250
# 1/1 - 0s - loss: 0.1710 - binary_accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 239/250
# 1/1 - 0s - loss: 0.1705 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 240/250
# 1/1 - 0s - loss: 0.1701 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 241/250
# 1/1 - 0s - loss: 0.1697 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 242/250
# 1/1 - 0s - loss: 0.1692 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 243/250
# 1/1 - 0s - loss: 0.1688 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 244/250
# 1/1 - 0s - loss: 0.1684 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 245/250
# 1/1 - 0s - loss: 0.1679 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 246/250
# 1/1 - 0s - loss: 0.1675 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 247/250
# 1/1 - 0s - loss: 0.1671 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 248/250
# 1/1 - 0s - loss: 0.1666 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 249/250
# 1/1 - 0s - loss: 0.1662 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 250/250
# 1/1 - 0s - loss: 0.1658 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step

# %%
print(model.predict(training_data).round())
# Out:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
